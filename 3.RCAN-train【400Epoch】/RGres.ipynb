# %% [markdown]
# 2022.12.18test

# %%
# %run train.py
# Out:
# => use gpu id: '0'
# ===> Loading datasets
# ===> Building model
# ===> Setting GPU
# ===> Setting Optimizer
# ===> Training
# Epoch = 1, lr = 0.0001
# ===> Epoch 1 Complete: Avg. Loss: 0.43427274
# ok!--------------------
# 1_eopch avg loss : 0.43427274
# Now the 1 time is :12.155656576156616
# Checkpoint saved to checkpoint/model_epoch_1.pth
# Epoch = 2, lr = 0.0001
# ===> Epoch 2 Complete: Avg. Loss: 0.24452854
# ok!--------------------
# 2_eopch avg loss : 0.24452854
# Now the 2 time is :8.444098711013794
# Checkpoint saved to checkpoint/model_epoch_2.pth
# Epoch = 3, lr = 0.0001
# ===> Epoch 3 Complete: Avg. Loss: 0.15440828
# ok!--------------------
# 3_eopch avg loss : 0.15440828
# Now the 3 time is :8.573253870010376
# Checkpoint saved to checkpoint/model_epoch_3.pth
# Epoch = 4, lr = 0.0001
# ===> Epoch 4 Complete: Avg. Loss: 0.12452105
# ok!--------------------
# 4_eopch avg loss : 0.12452105
# Now the 4 time is :8.635319471359253
# ...

# %% [markdown]
# 400

# %%
# %run train.py
# Out:
# => use gpu id: '0'
# ===> Loading datasets
# ===> Building model
# ===> Setting GPU
# ===> Setting Optimizer
# ===> Training
# Epoch = 1, lr = 0.0001
# ===> Epoch[1](10/10): Loss: 0.1849571466
# ===> Epoch 1 Complete: Avg. Loss: 0.32297430
# ok!--------------------
# 1_eopch avg loss : 0.32297430
# Now the 1 time is :17.475964307785034
# Checkpoint saved to checkpoint/model_epoch_1.pth
# Epoch = 2, lr = 0.0001
# ===> Epoch[2](10/10): Loss: 0.1113512591
# ===> Epoch 2 Complete: Avg. Loss: 0.13883940
# ok!--------------------
# 2_eopch avg loss : 0.13883940
# Now the 2 time is :10.373650550842285
# Checkpoint saved to checkpoint/model_epoch_2.pth
# Epoch = 3, lr = 0.0001
# ===> Epoch[3](10/10): Loss: 0.0881496444
# ===> Epoch 3 Complete: Avg. Loss: 0.09615590
# ok!--------------------
# 3_eopch avg loss : 0.09615590
# Now the 3 time is :10.413490772247314
# Checkpoint saved to checkpoint/model_epoch_3.pth
# Epoch = 4, lr = 0.0001
# ===> Epoch[4](10/10): Loss: 0.0607989132
# ...

# %% [markdown]
# 300

# %%
# %run train.py
# Out:
# => use gpu id: '0'
# ===> Loading datasets
# ===> Building model
# ===> Setting GPU
# ===> Setting Optimizer
# ===> Training
# Epoch = 1, lr = 0.0001
# ===> Epoch[1](10/56): Loss: 0.1468082070
# ===> Epoch[1](20/56): Loss: 0.0809393525
# ===> Epoch[1](30/56): Loss: 0.0755364597
# ===> Epoch[1](40/56): Loss: 0.0456261113
# ===> Epoch[1](50/56): Loss: 0.0574342422
# ===> Epoch 1 Complete: Avg. Loss: 0.10960875
# ok!--------------------
# 1_eopch avg loss : 0.10960875
# Now the 1 time is :53.48419237136841
# Checkpoint saved to checkpoint/model_epoch_1.pth
# Epoch = 2, lr = 0.0001
# ===> Epoch[2](10/56): Loss: 0.0519690476
# ===> Epoch[2](20/56): Loss: 0.0452164933
# ===> Epoch[2](30/56): Loss: 0.0459838808
# ===> Epoch[2](40/56): Loss: 0.0278535765
# ===> Epoch[2](50/56): Loss: 0.0340040587
# ===> Epoch 2 Complete: Avg. Loss: 0.04414474
# ok!--------------------
# 2_eopch avg loss : 0.04414474
# Now the 2 time is :53.5799822807312
# Checkpoint saved to checkpoint/model_epoch_2.pth
# ...

# %% [markdown]
# 测试对比

# %%
# %run train.py
# Out:
# => use gpu id: '0'
# ===> Loading datasets
# ===> Building model
# ===> Setting GPU
# ===> Setting Optimizer
# ===> Training
# Epoch = 1, lr = 0.0001
# ===> Epoch[1](10/56): Loss: 0.1405128986
# ===> Epoch[1](20/56): Loss: 0.1040213183
# ===> Epoch[1](30/56): Loss: 0.0672101676
# ===> Epoch[1](40/56): Loss: 0.0631214231
# ===> Epoch[1](50/56): Loss: 0.0710461214
# ===> Epoch 1 Complete: Avg. Loss: 0.12977500
# ok!--------------------
# 1_eopch avg loss : 0.12977500
# Now the 1 time is :121.06302452087402
# Checkpoint saved to checkpoint/model_epoch_1.pth
# Epoch = 2, lr = 0.0001
# ===> Epoch[2](10/56): Loss: 0.0576410070
# ===> Epoch[2](20/56): Loss: 0.0412141047
# ===> Epoch[2](30/56): Loss: 0.0490161180
# ===> Epoch[2](40/56): Loss: 0.0364278033
# ===> Epoch[2](50/56): Loss: 0.0376059823
# ===> Epoch 2 Complete: Avg. Loss: 0.04715654
# ok!--------------------
# 2_eopch avg loss : 0.04715654
# Now the 2 time is :53.021119117736816
# Checkpoint saved to checkpoint/model_epoch_2.pth
# ...

# %%
# %run eval.py --cuda --dataset Set5 --model checkpoint/model_epoch_50.pth
# Out:
# => use gpu id: '0'
# Processing  Set5_mat\baby_GT_x2.mat
# Processing  Set5_mat\bird_GT_x2.mat
# Processing  Set5_mat\butterfly_GT_x2.mat
# Processing  Set5_mat\head_GT_x2.mat
# Processing  Set5_mat\woman_GT_x2.mat
# Scale= 2
# Dataset= Set5
# PSNR_predicted= 36.50627498071328
# PSNR_bicubic= 33.69724420007842
# It takes average 0.1805063247680664s for processing
# Processing  Set5_mat\baby_GT_x3.mat
# Processing  Set5_mat\bird_GT_x3.mat
# Processing  Set5_mat\butterfly_GT_x3.mat
# Processing  Set5_mat\head_GT_x3.mat
# Processing  Set5_mat\woman_GT_x3.mat
# Scale= 3
# Dataset= Set5
# PSNR_predicted= 33.05535409109998
# PSNR_bicubic= 30.41144053782374
# It takes average 0.011167383193969727s for processing
# Processing  Set5_mat\baby_GT_x4.mat
# Processing  Set5_mat\bird_GT_x4.mat
# Processing  Set5_mat\butterfly_GT_x4.mat
# Processing  Set5_mat\head_GT_x4.mat
# Processing  Set5_mat\woman_GT_x4.mat
# Scale= 4
# Dataset= Set5
# PSNR_predicted= 30.875229873536956
# ...

# %%
model_epoch_50.pth
