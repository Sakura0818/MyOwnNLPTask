# %%
# %run train.py
# Out:
# => use gpu id: '0'
# ===> Loading datasets
# ===> Building model
# ===> Setting GPU
# /root/anaconda3/lib/python3.7/site-packages/torch/nn/_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# ===> Setting Optimizer
# ===> Training
# Epoch = 1, lr = 0.1
# ===> Epoch[1](1000/2897): Loss: 185.1556396484
# ===> Epoch[1](2000/2897): Loss: 151.9506225586
# ===> Epoch 1 Complete: Avg. Loss: 204.14897712
# ok!--------------------
# 1_eopch avg loss : 204.14897712
# Now the 1 time is :355.966365814209
# Checkpoint saved to checkpoint/model_epoch_1.pth
# Epoch = 2, lr = 0.1
# ===> Epoch[2](1000/2897): Loss: 202.2557983398
# ===> Epoch[2](2000/2897): Loss: 204.7955017090
# ===> Epoch 2 Complete: Avg. Loss: 183.88952958
# ok!--------------------
# 2_eopch avg loss : 183.88952958
# Now the 2 time is :361.04760456085205
# Checkpoint saved to checkpoint/model_epoch_2.pth
# Epoch = 3, lr = 0.1
# ...

# %%
# %run train.py
# Out:
# => use gpu id: '0'
# ===> Loading datasets
# ===> Building model
# ===> Setting GPU
# ===> Setting Optimizer
# ===> Training
# Epoch = 1, lr = 0.1
# D:\ProgramData\Anaconda\envs\swinir\lib\site-packages\torch\nn\_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# ===> Epoch[1](1/1260): Loss: 105176.8750000000
# ===> Epoch[1](2/1260): Loss: 7806.8525390625
# ===> Epoch[1](3/1260): Loss: 7655.6591796875
# ===> Epoch[1](4/1260): Loss: 1357.1391601562
# ===> Epoch[1](5/1260): Loss: 1986.0134277344
# ===> Epoch[1](6/1260): Loss: 955.7561035156
# ===> Epoch[1](7/1260): Loss: 3595.7944335938
# ===> Epoch[1](8/1260): Loss: 1925.0104980469
# ===> Epoch[1](9/1260): Loss: 684.9897460938
# ===> Epoch[1](10/1260): Loss: 1012.4464111328
# ===> Epoch[1](11/1260): Loss: 669.2340087891
# ===> Epoch[1](12/1260): Loss: 532.7708740234
# ===> Epoch[1](13/1260): Loss: 437.8194885254
# ...
