# %% [markdown]
# test

# %%
# %run train.py --train-file "BLAH_BLAH/91-image_x2.h5" \
                --eval-file "BLAH_BLAH/Set5_x2.h5" \
                --outputs-dir "BLAH_BLAH/outputs" \
                --scale 2 \
                --lr 1e-4 \
                --batch-size 16 \
                --num-epochs 400 \
                --num-workers 0 \
                --seed 123
# Out:
# 0_eopch avg loss : 0.00370018
# 0_eopch eval psnr: 34.66
# 1_eopch avg loss : 0.00078331
# 1_eopch eval psnr: 34.94

# %% [markdown]
# X2训练

# %%
# %run train.py --train-file "BLAH_BLAH/91-image_x2.h5" \
                --eval-file "BLAH_BLAH/Set5_x2.h5" \
                --outputs-dir "BLAH_BLAH/outputs" \
                --scale 2 \
                --lr 1e-4 \
                --batch-size 16 \
                --num-epochs 400 \
                --num-workers 0 \
                --seed 123
# Out:
# 0_eopch avg loss : 0.00377778
# 0_eopch eval psnr: 34.66
# 1_eopch avg loss : 0.00077882
# 1_eopch eval psnr: 35.05
# 2_eopch avg loss : 0.00072854
# 2_eopch eval psnr: 35.21
# 3_eopch avg loss : 0.00070665
# 3_eopch eval psnr: 34.98
# 4_eopch avg loss : 0.00069145
# 4_eopch eval psnr: 35.37
# 5_eopch avg loss : 0.00068154
# 5_eopch eval psnr: 35.46
# 6_eopch avg loss : 0.00067383
# 6_eopch eval psnr: 35.52
# 7_eopch avg loss : 0.00066768
# 7_eopch eval psnr: 35.56
# 8_eopch avg loss : 0.00065968
# 8_eopch eval psnr: 35.60
# 9_eopch avg loss : 0.00065604
# 9_eopch eval psnr: 35.65
# 10_eopch avg loss : 0.00065023
# 10_eopch eval psnr: 35.42
# 11_eopch avg loss : 0.00064619
# 11_eopch eval psnr: 35.72
# 12_eopch avg loss : 0.00064240
# 12_eopch eval psnr: 35.77
# 13_eopch avg loss : 0.00063914
# 13_eopch eval psnr: 35.77
# 14_eopch avg loss : 0.00063513
# 14_eopch eval psnr: 35.80
# 15_eopch avg loss : 0.00063160
# 15_eopch eval psnr: 35.62
# 16_eopch avg loss : 0.00062804
# ...

# %% [markdown]
# X4训练

# %%
# %run train.py --train-file "BLAH_BLAH/91-image_x4.h5" \
                --eval-file "BLAH_BLAH/Set5_x4.h5" \
                --outputs-dir "BLAH_BLAH/outputs" \
                --scale 4 \
                --lr 1e-4 \
                --batch-size 16 \
                --num-epochs 400 \
                --num-workers 0 \
                --seed 123
# Out:
# 0_eopch avg loss : 0.00493754
# 0_eopch eval psnr: 29.24
# 1_eopch avg loss : 0.00215499
# 1_eopch eval psnr: 29.43
# 2_eopch avg loss : 0.00209687
# 2_eopch eval psnr: 29.57
# 3_eopch avg loss : 0.00206484
# 3_eopch eval psnr: 29.63
# 4_eopch avg loss : 0.00204350
# 4_eopch eval psnr: 29.67
# 5_eopch avg loss : 0.00202931
# 5_eopch eval psnr: 29.74
# 6_eopch avg loss : 0.00201534
# 6_eopch eval psnr: 29.74
# 7_eopch avg loss : 0.00200417
# 7_eopch eval psnr: 29.68
# 8_eopch avg loss : 0.00199471
# 8_eopch eval psnr: 29.71
# 9_eopch avg loss : 0.00198677
# 9_eopch eval psnr: 29.84
# 10_eopch avg loss : 0.00197902
# 10_eopch eval psnr: 29.87
# 11_eopch avg loss : 0.00197080
# 11_eopch eval psnr: 29.88
# 12_eopch avg loss : 0.00196456
# 12_eopch eval psnr: 29.90
# 13_eopch avg loss : 0.00195842
# 13_eopch eval psnr: 29.83
# 14_eopch avg loss : 0.00195355
# 14_eopch eval psnr: 29.90
# 15_eopch avg loss : 0.00194860
# 15_eopch eval psnr: 29.93
# 16_eopch avg loss : 0.00194458
# ...
